# %% [markdown]
# # IzzyViz Use Case 2: Exploring Tuned Model Attention Differences
#
# This notebook demonstrates the **Explore** stage of IzzyViz for tuned-model comparison.
#
# Research goal:
#
# - Use one fixed QA prompt.
# - Compare attention behavior across Qwen-family base, instruct, math, coder, and distilled variants.
# - Identify not only visually interesting regions within each overview, but also **which same layer/head locations differ most from the base model**.
#
# Workflow:
#
# **Same Prompt -> Overview -> Same-Head Vector Comparison -> Difference × Salience Selection -> Representative Heads -> Hypotheses**
#
# This notebook reads existing outputs from `workflow/rag_cluster/multi_model_single_prompt_cluster/`. It does not rerun model inference by default.

# %% [markdown]
# ## 0. Clone and Install IzzyViz
#
# This use case can be opened directly from GitHub/Colab. The setup cell below finds an existing local `IzzyViz` checkout or clones `https://github.com/zoeyada/IzzyViz.git`, then installs it in editable mode.
#
# The notebook reads precomputed experiment outputs when available. If outputs are missing, set the corresponding `RUN_*_EXPERIMENT_IF_MISSING` flag to `True` to regenerate them. Regeneration loads large language models and can take substantial time.

# %%
from pathlib import Path
import os
import subprocess
import sys

REPO_URL = 'https://github.com/zoeyada/IzzyViz.git'
REPO_NAME = 'IzzyViz'

def find_or_clone_project_dir():
    cwd = Path.cwd().resolve()
    for candidate in [cwd, *cwd.parents]:
        if (candidate / 'izzyviz').is_dir() and (candidate / 'workflow').is_dir():
            return candidate

    workspace = Path('/content') if Path('/content').exists() else cwd
    repo_dir = workspace / REPO_NAME
    if not repo_dir.exists():
        subprocess.check_call(['git', 'clone', REPO_URL, str(repo_dir)])
    return repo_dir.resolve()

PROJECT_DIR = find_or_clone_project_dir()
os.chdir(PROJECT_DIR)
if str(PROJECT_DIR) not in sys.path:
    sys.path.insert(0, str(PROJECT_DIR))
try:
    import izzyviz  # noqa: F401
except ImportError:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', '-e', str(PROJECT_DIR)])
print('Using IzzyViz project:', PROJECT_DIR)
# Out:
# Using IzzyViz project: /home/cuizhouying/IzzyViz

# %%
from pathlib import Path
import json
import re
import subprocess
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display, Image, IFrame, Markdown

from izzyviz import (
    select_distinctive_attention_heads_by_features,
    visualize_distinctive_attention_head_maps,
    visualize_representative_head_candidates,
    visualize_attention_matrix,
    visualize_attention_overview_fast,
)

PROJECT_DIR = Path(PROJECT_DIR) if 'PROJECT_DIR' in globals() else Path.cwd()
if PROJECT_DIR.name != 'IzzyViz' and (PROJECT_DIR.parent / 'izzyviz').exists():
    PROJECT_DIR = PROJECT_DIR.parent

OUTPUT_ROOT = PROJECT_DIR / 'workflow' / 'rag_cluster' / 'multi_model_single_prompt_cluster'
SUMMARY_PATH = OUTPUT_ROOT / 'multi_model_summary.json'
RUN_TUNED_MODEL_EXPERIMENT_IF_MISSING = False

if not SUMMARY_PATH.exists() or not list(OUTPUT_ROOT.glob('*/head_features.npz')):
    if RUN_TUNED_MODEL_EXPERIMENT_IF_MISSING:
        script = PROJECT_DIR / 'workflow' / 'rag_cluster' / 'run_single_prompt_multi_model_cluster.py'
        subprocess.check_call([sys.executable, str(script)], cwd=str(PROJECT_DIR))
    else:
        raise FileNotFoundError(
            'Precomputed tuned-model outputs were not found under '
            f'{OUTPUT_ROOT}. Set RUN_TUNED_MODEL_EXPERIMENT_IF_MISSING=True to regenerate them, '
            'or provide the multi_model_single_prompt_cluster output folder.'
        )

USECASE_OUTPUT_DIR = PROJECT_DIR / 'workflow' / 'tuned_model_attention_exploration_outputs'
USECASE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
PDF_OUTPUT_DIR = PROJECT_DIR / 'workflow' / '0'
PDF_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

BASE_MODEL = 'Qwen2.5-1.5B'
ORDERED_LABELS = [
    'Qwen2.5-1.5B',
    'Qwen2.5-1.5B-Instruct',
    'Qwen2.5-1.5B-Math',
    'Qwen2.5-1.5B-Math-Instruct',
    'Qwen2.5-1.5B-Coder',
    'DeepSeek-R1-Distill-Qwen-1.5B',
]

print('Project:', PROJECT_DIR)
print('Outputs:', OUTPUT_ROOT)
print('Summary exists:', SUMMARY_PATH.exists())
# Out:
# Project: /home/cuizhouying/IzzyViz
# Outputs: /home/cuizhouying/IzzyViz/workflow/rag_cluster/multi_model_single_prompt_cluster
# Summary exists: True

# %% [markdown]
# ## 1. Load Multi-Model Metadata and Raw Head Features
#
# The input prompt is fixed across all model variants. Therefore, for every model we can compare the same `(layer, head)` location against the base model.
#
# This notebook uses raw per-head feature vectors saved from the attention tensors, not overview screenshots. Each head vector contains the same metrics used by IzzyViz clustering:
#
# - concentration
# - entropy
# - variance
# - threshold mass
# - top-percent mass
# - low-range dependency
# - long-range dependency
#
# The comparison is therefore:
#
# `same prompt, same analyzed token region, same layer, same head, feature-vector distance from base`

# %%
def load_json(path):
    with open(path, 'r', encoding='utf-8') as f:
        return json.load(f)

def safe_name(value):
    return re.sub(r'[^a-zA-Z0-9_]+', '_', str(value)).strip('_')

def load_feature_bundle(model_dir):
    path = Path(model_dir) / 'head_features.npz'
    if not path.exists():
        raise FileNotFoundError(
            f'Missing {path}. Re-run workflow/rag_cluster/run_single_prompt_multi_model_cluster.py '
            'after the feature-saving update.'
        )
    data = np.load(path, allow_pickle=True)
    head_infos = np.asarray(data['head_infos'], dtype=int)
    if 'features_layer_head' in data:
        features = data['features_layer_head']
        features_scaled = data['features_scaled_layer_head']
    else:
        # Backward compatibility with older experiment outputs that saved flat
        # [layer*head, feature] arrays. The head order is produced by
        # cluster_attention_heads as layer-major, head-minor.
        num_layers = int(head_infos[:, 0].max()) + 1
        num_heads = int(head_infos[:, 1].max()) + 1
        features = data['features'].reshape(num_layers, num_heads, -1)
        features_scaled = data['features_scaled'].reshape(num_layers, num_heads, -1)
    return {
        'features': features,
        'features_scaled': features_scaled,
        'feature_names': [str(x) for x in data['feature_names'].tolist()],
        'head_infos': head_infos,
        'path': path,
    }

summary = load_json(SUMMARY_PATH)
rows = []
feature_bundles = {}
for item in summary:
    if 'error' in item:
        rows.append({'model_label': item.get('model_label'), 'model_id': item.get('model_id'), 'error': item.get('error')})
        continue
    summary_path = Path(item['output_paths']['summary'])
    if not summary_path.exists():
        summary_path = OUTPUT_ROOT / Path(summary_path).parent.name / 'run_summary.json'
    model_dir = summary_path.parent
    bundle = load_feature_bundle(model_dir)
    feature_bundles[item['model_label']] = bundle
    run_summary = load_json(summary_path)
    cluster_sizes = {str(k): int(v) for k, v in run_summary.get('cluster_sizes', {}).items()}
    total_heads = sum(cluster_sizes.values()) or np.nan
    probs = np.array(list(cluster_sizes.values()), dtype=float) / total_heads
    cluster_entropy = float(-(probs * np.log2(probs + 1e-12)).sum()) if total_heads else np.nan
    largest_cluster_fraction = float(max(cluster_sizes.values()) / total_heads) if total_heads else np.nan
    reps = run_summary.get('representatives', [])
    rep_layers = [int(r['layer']) for r in reps]
    rows.append({
        'model_label': item['model_label'],
        'model_id': item['model_id'],
        'seq_len': item.get('seq_len'),
        'model_dir': model_dir,
        'feature_path': bundle['path'],
        'feature_names': bundle['feature_names'],
        'cluster_entropy': cluster_entropy,
        'largest_cluster_fraction': largest_cluster_fraction,
        'rep_layer_mean': float(np.mean(rep_layers)) if rep_layers else np.nan,
        'rep_layer_span': int(max(rep_layers) - min(rep_layers)) if rep_layers else np.nan,
        'representatives': reps,
        'overview_merge': model_dir / 'overview_merge_tokens.png',
        'overview_no_merge': model_dir / 'overview_no_merge.png',
        'pca': model_dir / 'pca_scatter.png',
        'detail_heatmaps': sorted(model_dir.glob('cluster_*_L*_H*.pdf')),
    })

model_df = pd.DataFrame(rows).set_index('model_label').loc[ORDERED_LABELS].reset_index()
print('Feature names:', feature_bundles[BASE_MODEL]['feature_names'])
display(model_df[['model_label', 'seq_len', 'cluster_entropy', 'largest_cluster_fraction', 'rep_layer_mean', 'rep_layer_span', 'feature_path']])
# Out:
# Feature names: ['concentration', 'entropy', 'variance', 'threshold_mass', 'top_percent_mass', 'low_range', 'long_range']
#                      model_label  ...                                       feature_path
# 0                   Qwen2.5-1.5B  ...  /home/cuizhouying/IzzyViz/workflow/rag_cluster...
# 1          Qwen2.5-1.5B-Instruct  ...  /home/cuizhouying/IzzyViz/workflow/rag_cluster...
# 2              Qwen2.5-1.5B-Math  ...  /home/cuizhouying/IzzyViz/workflow/rag_cluster...
# 3     Qwen2.5-1.5B-Math-Instruct  ...  /home/cuizhouying/IzzyViz/workflow/rag_cluster...
# 4             Qwen2.5-1.5B-Coder  ...  /home/cuizhouying/IzzyViz/workflow/rag_cluster...
# 5  DeepSeek-R1-Distill-Qwen-1.5B  ...  /home/cuizhouying/IzzyViz/workflow/rag_cluster...
#
# [6 rows x 7 columns]

# %% [markdown]
# ## 2. Observe: IzzyViz Overview Across the Qwen Family
#
# The overview remains the first visual step. It gives a global view of Layer × Head attention behavior before quantitative selection.
#
# Manual observations to consider:
#
# - Base and Instruct appear visually similar.
# - Math and Math-Instruct show stronger local changes than Base vs Instruct.
# - DeepSeek-R1-Distill-Qwen shows distinctive structures in several low-layer heads.
# - Coder remains broadly similar to the base model.
# - Attention sinks and recurring vertical structures appear across variants, suggesting a shared Qwen-family fingerprint.

# %%
import gc
import os
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

os.environ.setdefault('TOKENIZERS_PARALLELISM', 'false')
os.environ.setdefault('USE_TF', '0')
os.environ.setdefault('TRANSFORMERS_NO_TF', '1')
os.environ.setdefault('USE_FLAX', '0')
os.environ.setdefault('TRANSFORMERS_NO_FLAX', '1')
os.environ.setdefault('TRANSFORMERS_NO_TORCHVISION', '1')


def short_overview_label(label):
    return {
        'Qwen2.5-1.5B': 'Base',
        'Qwen2.5-1.5B-Instruct': 'Instruct',
        'Qwen2.5-1.5B-Math': 'Math',
        'Qwen2.5-1.5B-Math-Instruct': 'Math-Inst',
        'Qwen2.5-1.5B-Coder': 'Coder',
        'DeepSeek-R1-Distill-Qwen-1.5B': 'DeepSeek-R1-Distill',
    }.get(label, label)


def show_pdf(path, width=1120, height=720):
    path = Path(path)
    if not path.exists():
        raise FileNotFoundError(path)
    display(Markdown(f'PDF: `{path.relative_to(PROJECT_DIR)}`'))
    display(IFrame(src=str(path), width=width, height=height))


OVERVIEW_NUMERIC_PDF_DIR = PDF_OUTPUT_DIR / 'overview_fast_numeric_pdf'
OVERVIEW_NUMERIC_PDF_DIR.mkdir(parents=True, exist_ok=True)
REGENERATE_NUMERIC_OVERVIEW_PDFS = False

MODEL_IDS = dict(zip(model_df['model_label'], model_df['model_id']))
BASE_CONTEXT = (
    "The Rev. John J. Cavanaugh, C.S.C. served as president from 1946 to 1952. "
    "Cavanaugh's legacy at Notre Dame in the post-war years was devoted to raising academic standards "
    "and reshaping the university administration to suit it to an enlarged educational mission and an expanded "
    "student body and stressing advanced studies and research at a time when Notre Dame quadrupled in student census, "
    "undergraduate enrollment increased by more than half, and graduate student enrollment grew fivefold. "
    "Cavanaugh also established the Lobund Institute for Animal Studies and Notre Dame's Medieval Institute. "
    "Cavanaugh also presided over the construction of the Nieuwland Science Hall, Fisher Hall, and the Morris Inn, "
    "as well as the Hall of Liberal Arts (now O'Shaughnessy Hall), made possible by a donation from I.A. O'Shaughnessy, "
    "at the time the largest ever made to an American Catholic university. "
    "Cavanaugh also established a system of advisory councils at the university, which continue today and are vital "
    "to the university's governance and development."
)
QUESTION = 'Which institute involving animal life did Cavanaugh create at Notre Dame?'
ANSWER = 'Lobund Institute for Animal Studies'


def model_dtype():
    if not torch.cuda.is_available():
        return torch.float32
    if torch.cuda.is_bf16_supported():
        return torch.bfloat16
    return torch.float16


def build_prompt():
    x_text = f'Context: {BASE_CONTEXT}\nQuestion: {QUESTION}\n'
    answer_prefix = 'Answer:'
    prompt = x_text + answer_prefix + f' {ANSWER}'
    return prompt, x_text, answer_prefix


def numeric_labels(length):
    return [str(i) for i in range(length)]


def generate_numeric_overview_pdfs(model_label, model_id, no_merge_pdf, merge_pdf):
    print('Computing numeric-label overview:', model_label, model_id)
    tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=False)
    load_kwargs = dict(
        torch_dtype=model_dtype(),
        attn_implementation='eager',
        trust_remote_code=False,
    )
    if torch.cuda.is_available():
        load_kwargs['device_map'] = 'auto'
    model = AutoModelForCausalLM.from_pretrained(model_id, **load_kwargs)
    model.eval()

    prompt, x_text, answer_prefix = build_prompt()
    inputs = tokenizer(prompt, return_tensors='pt', add_special_tokens=False)
    first_device = next(model.parameters()).device
    inputs = {key: value.to(first_device) for key, value in inputs.items()}
    x_end = len(tokenizer(x_text, add_special_tokens=False)['input_ids'])
    answer_start = len(tokenizer(x_text + answer_prefix, add_special_tokens=False)['input_ids'])
    answer_end = int(inputs['input_ids'].shape[1])
    x_labels = numeric_labels(x_end)
    y_labels = numeric_labels(answer_end - answer_start)

    with torch.no_grad():
        outputs = model(
            **inputs,
            output_attentions=True,
            return_dict=True,
            use_cache=False,
        )

    visualize_attention_overview_fast(
        outputs.attentions,
        query_slice=(answer_start, answer_end),
        key_slice=(0, x_end),
        title=f'{model_label}: answer -> context/question attention',
        save_path=no_merge_pdf,
        shared_color_scale=True,
        shared_cbar=True,
        shared_cbar_label='Attention score',
        max_display_cols=96,
        figsize=(34, 58),
        wspace=0.26,
        hspace=0.30,
        close_after_save=True,
    )
    visualize_attention_overview_fast(
        outputs.attentions,
        query_slice=(answer_start, answer_end),
        key_slice=(0, x_end),
        title=f'{model_label}: answer -> context/question attention (merged virtual tokens)',
        save_path=merge_pdf,
        shared_color_scale=True,
        shared_cbar=True,
        shared_cbar_label='Attention score',
        merge_virtual_tokens=True,
        overview_top_n=3,
        show_merge_token_labels=True,
        merge_token_label_mode='index',
        merge_token_important_label_mode='index',
        merge_token_label_fontsize=3,
        x_labels=x_labels,
        y_labels=y_labels,
        figsize=(34, 58),
        wspace=0.34,
        hspace=0.38,
        close_after_save=True,
    )

    del outputs, model, tokenizer, inputs
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    plt.close('all')


overview_numeric_paths = []
for _, row in model_df.iterrows():
    model_label = row['model_label']
    model_id = MODEL_IDS[model_label]
    prefix = safe_name(model_label)
    no_merge_pdf = OVERVIEW_NUMERIC_PDF_DIR / f'{prefix}_overview_no_merge_numeric_labels.pdf'
    merge_pdf = OVERVIEW_NUMERIC_PDF_DIR / f'{prefix}_overview_merge_tokens_numeric_labels.pdf'
    if REGENERATE_NUMERIC_OVERVIEW_PDFS or not (no_merge_pdf.exists() and merge_pdf.exists()):
        generate_numeric_overview_pdfs(model_label, model_id, no_merge_pdf, merge_pdf)
    overview_numeric_paths.append((model_label, no_merge_pdf, merge_pdf))

for model_label, no_merge_pdf, merge_pdf in overview_numeric_paths:
    display(Markdown(f'### {short_overview_label(model_label)}'))
    show_pdf(no_merge_pdf)
    show_pdf(merge_pdf)
# Out:
# Computing numeric-label overview: Qwen2.5-1.5B Qwen/Qwen2.5-1.5B
# Computing numeric-label overview: Qwen2.5-1.5B-Instruct Qwen/Qwen2.5-1.5B-Instruct
# Computing numeric-label overview: Qwen2.5-1.5B-Math Qwen/Qwen2.5-Math-1.5B
# Computing numeric-label overview: Qwen2.5-1.5B-Math-Instruct Qwen/Qwen2.5-Math-1.5B-Instruct
# Computing numeric-label overview: Qwen2.5-1.5B-Coder Qwen/Qwen2.5-Coder-1.5B
# Computing numeric-label overview: DeepSeek-R1-Distill-Qwen-1.5B deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B
# /home/cuizhouying/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:188: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 12010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /__w/pytorch/pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|##########| 338/338 [00:00<00:00, 1348.99it/s]
# Loading weights: 100%|##########| 338/338 [00:24<00:00, 13.59it/s]
# Loading weights: 100%|##########| 338/338 [00:25<00:00, 13.04it/s]
# Loading weights: 100%|##########| 338/338 [00:00<00:00, 1336.00it/s]
# Loading weights: 100%|##########| 338/338 [00:26<00:00, 12.87it/s]
# Loading weights: 100%|##########| 339/339 [00:29<00:00, 11.60it/s]
# ### Base
# PDF: `workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_overview_no_merge_numeric_labels.pdf`
#         <iframe
#             width="1120"
#             height="720"
#             src="/home/cuizhouying/IzzyViz/workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_overview_no_merge_numeric_labels.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# PDF: `workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_overview_merge_tokens_numeric_labels.pdf`
#         <iframe
#             width="1120"
#             height="720"
#             src="/home/cuizhouying/IzzyViz/workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_overview_merge_tokens_numeric_labels.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ### Instruct
# PDF: `workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Instruct_overview_no_merge_numeric_labels.pdf`
#         <iframe
#             width="1120"
#             height="720"
#             src="/home/cuizhouying/IzzyViz/workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Instruct_overview_no_merge_numeric_labels.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# PDF: `workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Instruct_overview_merge_tokens_numeric_labels.pdf`
#         <iframe
#             width="1120"
#             height="720"
#             src="/home/cuizhouying/IzzyViz/workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Instruct_overview_merge_tokens_numeric_labels.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ### Math
# PDF: `workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Math_overview_no_merge_numeric_labels.pdf`
#         <iframe
#             width="1120"
#             height="720"
#             src="/home/cuizhouying/IzzyViz/workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Math_overview_no_merge_numeric_labels.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# PDF: `workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Math_overview_merge_tokens_numeric_labels.pdf`
#         <iframe
#             width="1120"
#             height="720"
#             src="/home/cuizhouying/IzzyViz/workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Math_overview_merge_tokens_numeric_labels.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ### Math-Inst
# PDF: `workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Math_Instruct_overview_no_merge_numeric_labels.pdf`
#         <iframe
#             width="1120"
#             height="720"
#             src="/home/cuizhouying/IzzyViz/workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Math_Instruct_overview_no_merge_numeric_labels.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# PDF: `workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Math_Instruct_overview_merge_tokens_numeric_labels.pdf`
#         <iframe
#             width="1120"
#             height="720"
#             src="/home/cuizhouying/IzzyViz/workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Math_Instruct_overview_merge_tokens_numeric_labels.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ### Coder
# PDF: `workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Coder_overview_no_merge_numeric_labels.pdf`
#         <iframe
#             width="1120"
#             height="720"
#             src="/home/cuizhouying/IzzyViz/workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Coder_overview_no_merge_numeric_labels.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# PDF: `workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Coder_overview_merge_tokens_numeric_labels.pdf`
#         <iframe
#             width="1120"
#             height="720"
#             src="/home/cuizhouying/IzzyViz/workflow/0/overview_fast_numeric_pdf/Qwen2_5_1_5B_Coder_overview_merge_tokens_numeric_labels.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ### DeepSeek-R1-Distill
# PDF: `workflow/0/overview_fast_numeric_pdf/DeepSeek_R1_Distill_Qwen_1_5B_overview_no_merge_numeric_labels.pdf`
#         <iframe
#             width="1120"
#             height="720"
#             src="/home/cuizhouying/IzzyViz/workflow/0/overview_fast_numeric_pdf/DeepSeek_R1_Distill_Qwen_1_5B_overview_no_merge_numeric_labels.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# PDF: `workflow/0/overview_fast_numeric_pdf/DeepSeek_R1_Distill_Qwen_1_5B_overview_merge_tokens_numeric_labels.pdf`
#         <iframe
#             width="1120"
#             height="720"
#             src="/home/cuizhouying/IzzyViz/workflow/0/overview_fast_numeric_pdf/DeepSeek_R1_Distill_Qwen_1_5B_overview_merge_tokens_numeric_labels.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 3. Select: Same-Layer Same-Head Vector Differences from Base
#
# This is the main tuned-model comparison step.
#
# For every target model and every `(layer, head)`, IzzyViz compares:
#
# `target_features[layer, head, :]` vs `base_features[layer, head, :]`
#
# The vector distance is the **relative difference**. The norm of the target head vector is the **absolute salience**. IzzyViz then ranks heads by:
#
# `combined_score = normalized_relative_difference × normalized_absolute_salience`
#
# This directly addresses the issue that a head can be different but weak, or strong but not different. The selected heads are both.

# %%
base_features = feature_bundles[BASE_MODEL]['features']
feature_names = feature_bundles[BASE_MODEL]['feature_names']
comparison_results = {}
comparison_rows = []


def save_selection_heatmap_pdf(matrix, top_records, title, path, cmap=None):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    num_layers, num_heads = matrix.shape
    fig, ax = plt.subplots(figsize=(max(7, num_heads * 0.55), max(5, num_layers * 0.22)))
    im = ax.imshow(matrix, aspect='auto', cmap=cmap)
    ax.set_title(title)
    ax.set_xlabel('Head')
    ax.set_ylabel('Layer')
    ax.set_xticks(np.arange(num_heads))
    ax.set_yticks(np.arange(num_layers))
    ax.tick_params(labelsize=7)
    for record in top_records:
        layer = int(record['layer'])
        head = int(record['head'])
        rank = int(record['rank'])
        ax.scatter([head], [layer], s=90, facecolors='none', edgecolors='#6f1ab6', linewidths=1.6)
        ax.text(head, layer, str(rank), ha='center', va='center', color='#6f1ab6', fontsize=7, fontweight='bold')
    fig.colorbar(im, ax=ax, fraction=0.035, pad=0.02)
    fig.tight_layout()
    fig.savefig(path, bbox_inches='tight')
    plt.close(fig)


for model_label in ORDERED_LABELS:
    if model_label == BASE_MODEL:
        continue
    target_features = feature_bundles[model_label]['features']
    out_dir = USECASE_OUTPUT_DIR / safe_name(model_label) / 'feature_difference_from_base'
    result = select_distinctive_attention_heads_by_features(
        target_features=target_features,
        reference_features=base_features,
        feature_names=feature_names,
        top_k=12,
        scale='robust',
        distance_metric='euclidean',
        salience_method='norm',
        output_dir=out_dir,
        run_name=f'{model_label}_vs_{BASE_MODEL}',
        plot_heatmaps=True,
    )
    comparison_results[model_label] = result
    selection = result['selection']
    pdf_dir = PDF_OUTPUT_DIR / safe_name(model_label) / 'feature_difference_from_base'
    save_selection_heatmap_pdf(
        selection['relative_scores_normalized'],
        selection['top_records'],
        f'{model_label}_vs_{BASE_MODEL}: normalized relative difference',
        pdf_dir / 'relative_difference_heatmap.pdf',
        cmap=plt.get_cmap('Purples'),
    )
    save_selection_heatmap_pdf(
        selection['salience_scores_normalized'],
        selection['top_records'],
        f'{model_label}_vs_{BASE_MODEL}: normalized absolute salience',
        pdf_dir / 'absolute_salience_heatmap.pdf',
        cmap=plt.get_cmap('Purples'),
    )
    save_selection_heatmap_pdf(
        selection['combined_scores'],
        selection['top_records'],
        f'{model_label}_vs_{BASE_MODEL}: distinctive selection score',
        pdf_dir / 'combined_distinctive_score_heatmap.pdf',
        cmap=plt.get_cmap('Purples'),
    )
    top = result['top_records'][0]
    comparison_rows.append({
        'model_label': model_label,
        'mean_same_head_distance': float(np.mean(result['relative_scores'])),
        'max_same_head_distance': float(np.max(result['relative_scores'])),
        'mean_target_salience': float(np.mean(result['salience_scores'])),
        'top_layer': top['layer'],
        'top_head': top['head'],
        'top_combined_score': top['combined_score'],
        'top_relative_norm': top['relative_score_normalized'],
        'top_salience_norm': top['salience_score_normalized'],
        'combined_heatmap': result['output_paths']['combined_distinctive_score_heatmap'],
    })

comparison_df = pd.DataFrame(comparison_rows).sort_values('mean_same_head_distance', ascending=False)
display(comparison_df[['model_label', 'mean_same_head_distance', 'max_same_head_distance', 'top_layer', 'top_head', 'top_combined_score', 'top_relative_norm', 'top_salience_norm']])
# Out:
#                      model_label  ...  top_salience_norm
# 2     Qwen2.5-1.5B-Math-Instruct  ...           0.564354
# 4  DeepSeek-R1-Distill-Qwen-1.5B  ...           0.563310
# 1              Qwen2.5-1.5B-Math  ...           0.515734
# 3             Qwen2.5-1.5B-Coder  ...           0.609920
# 0          Qwen2.5-1.5B-Instruct  ...           0.677805
#
# [5 rows x 8 columns]

# %% [markdown]
# ## 4. Difference Maps in IzzyViz Select Style
#
# The map below is a library-generated Select-stage visualization. Each row is a target model compared against the base model, and each cell is the combined difference × salience score for the same `(layer, head)` location.
#
# These maps are computed from raw attention-derived feature vectors, not screenshot pixels. The base-vs-base zero map is omitted.

# %%
diff_map_result = visualize_distinctive_attention_head_maps(
    comparison_results,
    model_order=list(comparison_df['model_label']),
    score_key='combined_scores',
    top_n=8,
    title='Same-Head Feature Difference × Salience vs Qwen2.5-1.5B',
    output_dir=USECASE_OUTPUT_DIR,
    filename='same_head_feature_difference_select_map.png',
    layout='grid',
    ncols=5,
    panel_width=3.0,
    panel_height=4.7,
    tick_every=2,
    close_after_save=False,
)

import matplotlib.patheffects as pe

diff_fig = diff_map_result['figure']
diff_axes = diff_map_result['axes']
diff_model_order = list(comparison_df['model_label'])
for idx, label in enumerate(diff_model_order):
    ax = diff_axes[idx // 5, idx % 5]
    ax.set_title('', loc='left')
    ax.set_title(label, loc='center', fontsize=8.0, fontweight='bold', color='#6f1ab6', pad=6)
    for collection in ax.collections:
        sizes = collection.get_sizes()
        if len(sizes):
            collection.set_sizes(np.full_like(sizes, 46, dtype=float))
            collection.set_facecolor('white')
            collection.set_edgecolor('#6f1ab6')
            collection.set_alpha(0.92)
            collection.set_linewidth(0.9)
            collection.set_path_effects([pe.Stroke(linewidth=1.4, foreground='white'), pe.Normal()])
    for text in ax.texts:
        text.set_fontsize(5.2)
        text.set_color('#4b0082')
        text.set_path_effects([pe.Stroke(linewidth=0.7, foreground='white'), pe.Normal()])
diff_fig.subplots_adjust(left=0.04, right=0.91, top=0.86, bottom=0.11, wspace=0.22, hspace=0.10)
diff_fig.savefig(diff_map_result['output_path'], dpi=220, bbox_inches='tight')
diff_fig.savefig(PDF_OUTPUT_DIR / 'same_head_feature_difference_select_map.pdf', bbox_inches='tight')
plt.close(diff_fig)

show_path = diff_map_result['output_path']
display(Image(filename=show_path, width=1500))

for _, row in comparison_df.iterrows():
    display(Markdown(f"### {row['model_label']} vs {BASE_MODEL}: top distinctive heads"))
    records = comparison_results[row['model_label']]['top_records'][:8]
    display(pd.DataFrame(records)[[
        'rank', 'layer', 'head', 'combined_score',
        'relative_score_normalized', 'salience_score_normalized',
        'relative_score', 'salience_score'
    ]])
# Out:
# ### Qwen2.5-1.5B-Math-Instruct vs Qwen2.5-1.5B: top distinctive heads
#    rank  layer  head  ...  salience_score_normalized  relative_score  salience_score
# 0     1     23     4  ...                   0.564354       11.432045       15.213517
# 1     2      6     7  ...                   0.718139        5.876488       19.262107
# 2     3     19     3  ...                   0.692308        5.548663       18.582068
# 3     4      8     3  ...                   0.809441        4.568803       21.665758
# 4     5     19     5  ...                   0.501545        7.079197       13.559976
# 5     6     14     4  ...                   0.451279        5.979401       12.236653
# 6     7     16     2  ...                   0.276502        9.585640        7.635433
# 7     8     17     4  ...                   0.174851       10.682164        4.959320
#
# [8 rows x 8 columns]
# ### DeepSeek-R1-Distill-Qwen-1.5B vs Qwen2.5-1.5B: top distinctive heads
#    rank  layer  head  ...  salience_score_normalized  relative_score  salience_score
# 0     1     23     4  ...                   0.563310        9.007863       12.072016
# 1     2      2     4  ...                   0.417631        9.886950        9.045461
# 2     3      2     3  ...                   0.536866        5.758865       11.522642
# 3     4     19     5  ...                   0.251297       11.732197        5.589781
# 4     5     23     2  ...                   0.417483        6.256145        9.042390
# 5     6     19     3  ...                   0.779527        3.116355       16.564063
# 6     7     16     2  ...                   0.386069        5.744547        8.389732
# 7     8     23     1  ...                   0.504847        3.758965       10.857421
#
# [8 rows x 8 columns]
# ### Qwen2.5-1.5B-Math vs Qwen2.5-1.5B: top distinctive heads
#    rank  layer  head  ...  salience_score_normalized  relative_score  salience_score
# 0     1     23     4  ...                   0.515734        7.647562       10.526105
# 1     2     19     5  ...                   0.290537        9.998991        6.048402
# 2     3      6     7  ...                   0.682202        3.687208       13.836082
# 3     4     17     4  ...                   0.274933        8.378041        5.738134
# 4     5     16     2  ...                   0.400703        4.710412        8.238886
# 5     6      2     4  ...                   0.279077        6.615848        5.820541
# 6     7     19     3  ...                   0.779932        2.271138       15.779301
# 7     8     23     2  ...                   0.791488        2.184859       16.009073
#
# [8 rows x 8 columns]
# ### Qwen2.5-1.5B-Coder vs Qwen2.5-1.5B: top distinctive heads
#    rank  layer  head  ...  salience_score_normalized  relative_score  salience_score
# 0     1     23     4  ...                   0.609920       11.121306       14.284634
# 1     2     19     5  ...                   0.468378        6.669320       11.013243
# 2     3      8     4  ...                   0.391740        7.327182        9.241946
# 3     4     16     2  ...                   0.403412        5.044987        9.511709
# 4     5     17     4  ...                   0.378815        5.062092        8.943200
# 5     6     24     2  ...                   0.269634        5.766446        6.419769
# 6     7     12     2  ...                   0.356053        3.415885        8.417117
# 7     8     23     1  ...                   0.431681        2.742509       10.165083
#
# [8 rows x 8 columns]
# ### Qwen2.5-1.5B-Instruct vs Qwen2.5-1.5B: top distinctive heads
#    rank  layer  head  ...  salience_score_normalized  relative_score  salience_score
# 0     1     25     7  ...                   0.677805        4.637941       13.373036
# 1     2     19     5  ...                   0.397974        7.753872        7.962021
# 2     3     23     6  ...                   0.378959        4.143250        7.594320
# 3     4     17     4  ...                   0.528082        2.082321       10.477871
# 4     5     19     3  ...                   0.850729        1.047047       16.716820
# 5     6     14     4  ...                   0.614865        1.301723       12.155982
# 6     7     16     0  ...                   0.335864        1.937854        6.761002
# 7     8     12     1  ...                   0.466768        1.262285        9.292258
#
# [8 rows x 8 columns]

# %% [markdown]
# ## 5. Representative Heads and Candidate Heatmaps
#
# This library-generated view summarizes clustering representatives and highlights representatives that also appear among the top distinctive heads.
#
# It is useful because a head can be:
#
# - distinctive relative to the base model;
# - representative of a broader cluster within the target model;
# - or both.
#
# Heads that satisfy both criteria are strong candidates for detailed inspection.

# %%
representatives_by_model = {
    row['model_label']: row['representatives']
    for _, row in model_df.iterrows()
}
distinctive_records_by_model = {
    label: result['top_records']
    for label, result in comparison_results.items()
}
rep_result = visualize_representative_head_candidates(
    representatives_by_model,
    distinctive_records_by_model=distinctive_records_by_model,
    model_order=ORDERED_LABELS,
    title='Cluster Representatives and Distinctive-Head Candidates',
    output_dir=USECASE_OUTPUT_DIR,
    filename='representative_head_candidates.png',
    max_distinctive_rank=12,
    close_after_save=False,
)

rep_fig = rep_result['figure']
rep_ax = rep_result['axis']
max_layer = max(row['layer'] for row in rep_result['rows']) if rep_result['rows'] else 0
short_model_labels = {
    'Qwen2.5-1.5B': 'Base',
    'Qwen2.5-1.5B-Instruct': 'Inst',
    'Qwen2.5-1.5B-Math': 'Math',
    'Qwen2.5-1.5B-Math-Instruct': 'Math-Inst',
    'Qwen2.5-1.5B-Coder': 'Coder',
    'DeepSeek-R1-Distill-Qwen-1.5B': 'DS-R1',
}
rep_fig.set_size_inches(3.5, 2.35)
rep_ax.set_yticks(np.arange(len(ORDERED_LABELS)))
rep_ax.set_yticklabels([short_model_labels.get(label, label) for label in ORDERED_LABELS], fontsize=4.7)
rep_ax.set_xlim(-0.55, max_layer + 0.55)
rep_ax.set_ylim(len(ORDERED_LABELS) - 0.45, -0.65)
rep_ax.tick_params(axis='x', labelsize=4.8, length=2)
rep_ax.tick_params(axis='y', length=2)
rep_ax.set_xlabel('Layer', fontsize=5.0, labelpad=3)
rep_ax.set_title('Representative Heads', fontsize=6.4, fontweight='bold', pad=11)
for collection in rep_ax.collections:
    sizes = collection.get_sizes()
    if len(sizes):
        collection.set_sizes(np.where(sizes > 120, 38, 24))
for text in rep_ax.texts:
    text.set_visible(False)
label_offsets = [0.16, -0.16, 0.29, -0.29]
for model_idx, model_label in enumerate(ORDERED_LABELS):
    model_rows = sorted(
        [row for row in rep_result['rows'] if row['model_label'] == model_label],
        key=lambda row: row['layer'],
    )
    cluster_id = 0
    prev_x = None
    for row in model_rows:
        x = row['layer']
        if prev_x is None or x - prev_x > 1.15:
            cluster_id = 0
        else:
            cluster_id += 1
        prev_x = x
        y_offset = label_offsets[cluster_id % len(label_offsets)]
        rep_ax.text(
            x,
            model_idx + y_offset,
            f"H{row['head']}",
            fontsize=3.25,
            ha='center',
            va='center',
            color='black',
            zorder=5,
            bbox=dict(facecolor='white', edgecolor='none', alpha=0.68, pad=0.12),
        )
rep_ax.margins(x=0.0, y=0.04)
legend = rep_ax.get_legend()
legend_handles = legend.legend_handles if legend is not None else []
legend_labels = [text.get_text() for text in legend.get_texts()] if legend is not None else []
if legend is not None:
    legend.remove()
rep_ax.legend(
    handles=legend_handles,
    labels=['Rep.', 'Rep. + top diff.'],
    loc='upper center',
    bbox_to_anchor=(0.5, -0.39),
    borderaxespad=0.0,
    frameon=False,
    ncol=2,
    fontsize=3.9,
    markerscale=0.40,
    handletextpad=0.18,
    columnspacing=0.65,
)
rep_fig.subplots_adjust(left=0.16, right=0.985, top=0.73, bottom=0.43)
rep_fig.savefig(rep_result['output_path'], dpi=300, bbox_inches='tight')
rep_fig.savefig(PDF_OUTPUT_DIR / 'representative_head_candidates.pdf', bbox_inches='tight')
plt.close(rep_fig)

display(Image(filename=rep_result['output_path'], width=420))
rep_df = pd.DataFrame(rep_result['rows'])
display(rep_df.sort_values(['model_label', 'cluster']))
# Out:
#                       model_label  cluster  layer  head  also_top_distinctive
# 25  DeepSeek-R1-Distill-Qwen-1.5B        0     14     3                 False
# 26  DeepSeek-R1-Distill-Qwen-1.5B        1     12     1                 False
# 27  DeepSeek-R1-Distill-Qwen-1.5B        2     23     8                 False
# 28  DeepSeek-R1-Distill-Qwen-1.5B        3      6     2                 False
# 29  DeepSeek-R1-Distill-Qwen-1.5B        4     17    11                 False
# 0                    Qwen2.5-1.5B        0     19     5                 False
# 1                    Qwen2.5-1.5B        1     20     3                 False
# 2                    Qwen2.5-1.5B        2     10     2                 False
# 3                    Qwen2.5-1.5B        3     26     2                 False
# 4                    Qwen2.5-1.5B        4      9     0                 False
# 20             Qwen2.5-1.5B-Coder        0     17     5                 False
# 21             Qwen2.5-1.5B-Coder        1     21     1                 False
# 22             Qwen2.5-1.5B-Coder        2     14     3                  True
# 23             Qwen2.5-1.5B-Coder        3     22     7                 False
# 24             Qwen2.5-1.5B-Coder        4     23     1                  True
# 5           Qwen2.5-1.5B-Instruct        0     14     3                 False
# 6           Qwen2.5-1.5B-Instruct        1     23     8                 False
# 7           Qwen2.5-1.5B-Instruct        2     11     1                 False
# 8           Qwen2.5-1.5B-Instruct        3     18     1                 False
# 9           Qwen2.5-1.5B-Instruct        4      4     0                 False
# 10              Qwen2.5-1.5B-Math        0      6     2                 False
# 11              Qwen2.5-1.5B-Math        1     27     1                 False
# 12              Qwen2.5-1.5B-Math        2     25    11                 False
# 13              Qwen2.5-1.5B-Math        3     19     3                  True
# 14              Qwen2.5-1.5B-Math        4      2     4                  True
# 15     Qwen2.5-1.5B-Math-Instruct        0     14     4                  True
# 16     Qwen2.5-1.5B-Math-Instruct        1      6     7                  True
# 17     Qwen2.5-1.5B-Math-Instruct        2     27    11                 False
# 18     Qwen2.5-1.5B-Math-Instruct        3     17     5                 False
# 19     Qwen2.5-1.5B-Math-Instruct        4     26     1                 False

# %% [markdown]
# ## 6. Long-Context Attention Matrix Comparison
#
# After selecting candidate heads, inspect concrete attention matrices with the standard IzzyViz long-context view.
#
# This example compares the same head, `L23H4`, for the base model and the most different model from the feature-vector ranking. The function used here is:
#
# `visualize_attention_matrix(..., merge_virtual_tokens=True)`
#
# Virtual-token merging keeps the long context readable while preserving the strongest token-level structures.

# %%
LONG_CONTEXT_OUTPUT_DIR = USECASE_OUTPUT_DIR / 'long_context_attention_L23H4'
LONG_CONTEXT_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
LONG_CONTEXT_PDF_DIR = PDF_OUTPUT_DIR / 'long_context_attention_L23H4'
LONG_CONTEXT_PDF_DIR.mkdir(parents=True, exist_ok=True)

# Inspect figures: choose any layer/head here. The default follows the strongest
# distinctive same-head difference found above.
INSPECT_MODEL = comparison_df.iloc[0]['model_label']
INSPECT_LAYER = int(comparison_df.iloc[0]['top_layer'])
INSPECT_HEAD = int(comparison_df.iloc[0]['top_head'])
INSPECT_MODELS = [BASE_MODEL, INSPECT_MODEL]

inspect_paths = {
    label: LONG_CONTEXT_OUTPUT_DIR / f"{safe_name(label)}_L{INSPECT_LAYER}_H{INSPECT_HEAD}_inspect.png"
    for label in INSPECT_MODELS
}
inspect_pdf_paths = {
    label: LONG_CONTEXT_PDF_DIR / f"{safe_name(label)}_L{INSPECT_LAYER}_H{INSPECT_HEAD}_inspect.pdf"
    for label in INSPECT_MODELS
}

if (
    not all(path.exists() for path in inspect_paths.values())
    or not all(path.exists() for path in inspect_pdf_paths.values())
):
    import gc
    import os
    import torch
    from transformers import AutoModelForCausalLM, AutoTokenizer

    os.environ.setdefault('TOKENIZERS_PARALLELISM', 'false')
    os.environ.setdefault('USE_TF', '0')
    os.environ.setdefault('TRANSFORMERS_NO_TF', '1')
    os.environ.setdefault('USE_FLAX', '0')
    os.environ.setdefault('TRANSFORMERS_NO_FLAX', '1')
    os.environ.setdefault('TRANSFORMERS_NO_TORCHVISION', '1')

    MODEL_IDS = dict(zip(model_df['model_label'], model_df['model_id']))
    BASE_CONTEXT = (
        "The Rev. John J. Cavanaugh, C.S.C. served as president from 1946 to 1952. "
        "Cavanaugh's legacy at Notre Dame in the post-war years was devoted to raising academic standards "
        "and reshaping the university administration to suit it to an enlarged educational mission and an expanded "
        "student body and stressing advanced studies and research at a time when Notre Dame quadrupled in student census, "
        "undergraduate enrollment increased by more than half, and graduate student enrollment grew fivefold. "
        "Cavanaugh also established the Lobund Institute for Animal Studies and Notre Dame's Medieval Institute. "
        "Cavanaugh also presided over the construction of the Nieuwland Science Hall, Fisher Hall, and the Morris Inn, "
        "as well as the Hall of Liberal Arts (now O'Shaughnessy Hall), made possible by a donation from I.A. O'Shaughnessy, "
        "at the time the largest ever made to an American Catholic university. "
        "Cavanaugh also established a system of advisory councils at the university, which continue today and are vital "
        "to the university's governance and development."
    )
    QUESTION = 'Which institute involving animal life did Cavanaugh create at Notre Dame?'
    ANSWER = 'Lobund Institute for Animal Studies'

    def model_dtype():
        if not torch.cuda.is_available():
            return torch.float32
        if torch.cuda.is_bf16_supported():
            return torch.bfloat16
        return torch.float16

    def build_prompt():
        x_text = f'Context: {BASE_CONTEXT}\nQuestion: {QUESTION}\n'
        answer_prefix = 'Answer:'
        prompt = x_text + answer_prefix + f' {ANSWER}'
        return prompt, x_text, answer_prefix

    for label in INSPECT_MODELS:
        if inspect_paths[label].exists() and inspect_pdf_paths[label].exists():
            continue
        model_id = MODEL_IDS[label]
        print('Computing inspect attention:', label, model_id, f'L{INSPECT_LAYER} H{INSPECT_HEAD}')
        tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
        load_kwargs = dict(
            torch_dtype=model_dtype(),
            attn_implementation='eager',
            trust_remote_code=True,
        )
        if torch.cuda.is_available():
            load_kwargs['device_map'] = 'auto'
        model = AutoModelForCausalLM.from_pretrained(model_id, **load_kwargs)
        model.eval()

        prompt, x_text, answer_prefix = build_prompt()
        inputs = tokenizer(prompt, return_tensors='pt', add_special_tokens=False)
        first_device = next(model.parameters()).device
        inputs = {key: value.to(first_device) for key, value in inputs.items()}
        tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'][0])
        x_end = len(tokenizer(x_text, add_special_tokens=False)['input_ids'])
        answer_start = len(tokenizer(x_text + answer_prefix, add_special_tokens=False)['input_ids'])
        answer_end = len(tokens)

        with torch.no_grad():
            outputs = model(
                **inputs,
                output_attentions=True,
                return_dict=True,
                use_cache=False,
            )
        matrix = outputs.attentions[INSPECT_LAYER][0, INSPECT_HEAD, answer_start:answer_end, :x_end].detach().float().cpu().numpy()
        ax, _ = visualize_attention_matrix(
            matrix,
            x_labels=tokens[:x_end],
            y_labels=tokens[answer_start:answer_end],
            title=f'{label}: L{INSPECT_LAYER} H{INSPECT_HEAD} answer -> context/question',
            xlabel='Context + Question',
            ylabel='Answer',
            top_n=20,
            enlarged_size=2.0,
            gamma=1.5,
            cmap='Purples',
            merge_virtual_tokens=True,
            virtual_token_min_run=2,
            length_threshold=64,
            if_interval=False,
            if_top_cells=True,
            show_scores_in_enlarged_cells=False,
            lean_more=True,
            save_path=str(inspect_paths[label]),
            close_after_save=False,
        )
        ax.figure.savefig(inspect_pdf_paths[label], bbox_inches='tight')
        plt.close(ax.figure)
        del outputs, model, tokenizer, inputs
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

for label, path in inspect_paths.items():
    display(Markdown(f'### Inspect: {label} L{INSPECT_LAYER} H{INSPECT_HEAD}'))
    display(Image(filename=str(path), width=1050))
    display(Markdown(f'PDF: `{inspect_pdf_paths[label].relative_to(PROJECT_DIR)}`'))
# Out:
# ### Inspect: Qwen2.5-1.5B L23 H4
# PDF: `workflow/0/long_context_attention_L23H4/Qwen2_5_1_5B_L23_H4_inspect.pdf`
# ### Inspect: Qwen2.5-1.5B-Math-Instruct L23 H4
# PDF: `workflow/0/long_context_attention_L23H4/Qwen2_5_1_5B_Math_Instruct_L23_H4_inspect.pdf`

# %% [markdown]
# ## 7. Notes for Paper Observations
#
# Use this section to refine paper text after inspecting the figures.
#
# ### Observation: base vs instruct
#
# The attention overview of Qwen2.5-1.5B is visually similar to Qwen2.5-1.5B-Instruct. The same-head feature distance table provides quantitative support: if Instruct has low mean same-head distance relative to other variants, this supports the claim that instruction tuning preserves much of the global attention topology.
#
# ### Observation: math tuning
#
# If Math and Math-Instruct have larger same-head distances than Instruct, that supports the hypothesis that domain-specific mathematical tuning reshapes attention behavior more strongly than instruction tuning alone.
#
# ### Observation: distilled model
#
# If DeepSeek-R1-Distill-Qwen-1.5B has the highest mean/max same-head feature distance and several top distinctive heads in low layers, this supports the observation that distillation changes early-stage information routing. Unlike an early/middle/late thumbnail heuristic, this claim is grounded in specific layer/head feature-vector differences.
#
# ### Observation: coder model
#
# If Coder has moderate or low same-head distances while its overview remains visually similar to the base model, this supports the hypothesis that coding specialization may rely less on large-scale attention-topology changes and more on other model components or localized changes.
#
# ### Observation: shared attention fingerprint
#
# Recurring overview structures and repeated representative-head layer bands across variants suggest a shared Qwen-family attention fingerprint. Distinctive selection highlights local deviations from that shared structure.
#
# ### TODO: Manual notes
#
# - TODO: Add exact layer/head examples from the final heatmaps.
# - TODO: Compare whether top distinctive heads overlap with clustering representatives.
# - TODO: Decide which model-pair heatmaps are strong enough for the demo paper figure.
